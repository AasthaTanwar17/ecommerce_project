# %%
datasets = [
    {
        "file_name":"orders"
    },
    {
        "file_name":"customers"
    },
    {
        "file_name":"order_items"
        }
]

# %%
dbutils.jobs.taskValues.set("output_datasets", datasets)
